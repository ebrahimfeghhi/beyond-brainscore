# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
SP_SL_minus_GPT2XLU_sp_243 = np.load('/data/LLMs/brainscore/results_pereira/glass_brain_plots/SP+SL-GPT2-XLU-sp_out_of_sample_r2_243.npz')['426']
SP_SL_minus_GPT2XLU_sp_384 = np.load('/data/LLMs/brainscore/results_pereira/glass_brain_plots/SP+SL-GPT2-XLU-sp_out_of_sample_r2_384.npz')['426']
SP_SL_minus_GPT2XLU_sp = (SP_SL_minus_GPT2XLU_sp_384 + SP_SL_minus_GPT2XLU_sp_243)/2
SP_SL_minus_GPT2XLU_sp = SP_SL_minus_GPT2XLU_sp[~np.isnan(SP_SL_minus_GPT2XLU_sp)]

# %%
np.nanmin(SP_SL_minus_GPT2XLU_sp)
# Out:
# -0.03750690027908984

# %%
np.nanmean(SP_SL_minus_GPT2XLU_sp)
# Out:
# 0.0029013279617213584

# %%
plt.hist(SP_SL_minus_GPT2XLU_sp)
# Out:
# (array([  49.,  281., 1384., 4457., 3233.,  738.,  109.,   24.,    9.,
#           10.]),
#  array([-0.0375069 , -0.02688106, -0.01625521, -0.00562937,  0.00499647,
#          0.01562232,  0.02624816,  0.036874  ,  0.04749985,  0.05812569,
#          0.06875153]),
#  <BarContainer object of 10 artists>)
